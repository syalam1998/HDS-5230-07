# %% [markdown]
# **Name: Snigdha Yalam**
#
# **Course: HDS-5230-07**
# Assignment: Week 5 - COVID-19 Data Analysis**

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import requests
import zipfile
import os
from io import BytesIO

# %%
url = "https://coronadatascraper.com/timeseries.csv.zip"
response = requests.get(url)
response.raise_for_status()
data_dir = "covid_data"
os.makedirs(data_dir, exist_ok=True)
with zipfile.ZipFile(BytesIO(response.content), 'r') as zip_ref:
    zip_ref.extractall(data_dir)
csv_file = os.path.join(data_dir, "timeseries.csv")
df = dd.read_csv(csv_file, dtype={'population': 'float64', 'deaths': 'float64', 'cases': 'float64', 'state': 'object'}, assume_missing=True)

# %%
df_us = df[df['country'] == 'United States']
df_states = df_us.dropna(subset=['state'])

start_date = "2020-01-01"
end_date = "2021-02-28"
df_states['date'] = dd.to_datetime(df_states['date'], errors='coerce')
df_states = df_states[(df_states['date'] >= start_date) & (df_states['date'] <= end_date)]
def compute_per_capita_mortality(df):
    deaths = df.groupby('state').agg({'deaths': 'sum'}).compute()
    avg_population = df.groupby('state').agg({'population': 'mean'}).compute()
    per_capita_mortality = deaths['deaths'] / avg_population['population']
    return per_capita_mortality.dropna()
per_capita_mortality = compute_per_capita_mortality(df_states)
state_ranking = per_capita_mortality.sort_values(ascending=False)
print("Per-Capita Mortality Ranking:\n", state_ranking)
def compute_cfr(df):
    df['month'] = df['date'].dt.to_period('M')
    df_filtered = df[df['cases'] > 0]
    cfr_matrix = df_filtered.groupby(['state', 'month']).agg({'deaths': 'sum', 'cases': 'sum'}).compute()
    cfr_matrix['CFR'] = (cfr_matrix['deaths'] / cfr_matrix['cases']) * 100
    cfr_matrix = cfr_matrix.pivot_table(values='CFR', index='state', columns='month')
    return cfr_matrix.dropna(axis=1, how='all')
cfr_matrix = compute_cfr(df_states)
print("CFR Matrix:\n", cfr_matrix)

def compute_cfr_change_ranking(cfr_matrix):
    cfr_changes = cfr_matrix.diff(axis=1).sum(axis=1)
    return cfr_changes.sort_values(ascending=False).dropna()

cfr_change_ranking = compute_cfr_change_ranking(cfr_matrix)
print("CFR Change Ranking:\n", cfr_change_ranking)
# Out:
# Per-Capita Mortality Ranking:
#  state
# New York                        15.838824
# Texas                            9.136704
# Michigan                         8.862964
# Louisiana                        8.508834
# Georgia                          7.937739
# Illinois                         7.774370
# Mississippi                      7.038137
# New Jersey                       5.708752
# Pennsylvania                     5.698869
# Virginia                         5.131386
# Ohio                             3.920150
# Minnesota                        3.673553
# Iowa                             3.579520
# Florida                          3.422462
# Kentucky                         3.215970
# Colorado                         3.086699
# Alabama                          3.040476
# Missouri                         3.033844
# North Carolina                   2.869425
# Massachusetts                    2.517199
# Tennessee                        2.421777
# Nebraska                         2.328852
# South Carolina                   2.264921
# Maryland                         2.118821
# Kansas                           2.089336
# California                       2.077781
# Indiana                          1.958165
# Oklahoma                         1.814100
# Wisconsin                        1.786630
# Connecticut                      1.745896
# Arkansas                         1.652839
# New Mexico                       1.476186
# South Dakota                     1.437950
# Washington                       1.358826
# North Dakota                     1.055356
# Arizona                          1.032282
# Idaho                            0.835605
# Nevada                           0.790467
# West Virginia                    0.741299
# Montana                          0.556705
# Rhode Island                     0.505907
# New Hampshire                    0.455508
# Oregon                           0.439400
# Utah                             0.358138
# Washington, D.C.                 0.248312
# Delaware                         0.247037
# Vermont                          0.237781
# Maine                            0.210575
# Alaska                           0.163319
# Wyoming                          0.140680
# Hawaii                           0.030176
# United States Virgin Islands     0.014890
# Puerto Rico                      0.013317
# Guam                             0.011265
# Northern Mariana Islands         0.006710
# American Samoa                   0.000000
# dtype: float64
# CFR Matrix:
#  month                         2020-01   2020-02   2020-03    2020-04  \
# state
# Alabama                           NaN       NaN  0.670344   3.222166
# Alaska                            NaN       NaN  1.340996   2.439908
# Arizona                           0.0  0.000000  1.444484   3.728072
# Arkansas                          NaN       NaN  0.931025   1.920520
# California                        0.0  5.683564  2.173349   3.565176
# Colorado                          NaN       NaN  1.796194   4.443955
# Connecticut                       NaN       NaN  1.933488   6.451799
# Delaware                          NaN       NaN  2.335570   3.279130
# Florida                           NaN       NaN  1.403046   2.911739
# Georgia                           NaN       NaN  3.049293   3.966205
# Guam                              NaN       NaN  2.131783   3.631579
# Hawaii                            NaN       NaN  0.151172   1.804847
# Idaho                             NaN       NaN  1.386930   2.375170
# Illinois                          0.0  0.000000  1.310235   4.066047
# Indiana                           NaN       NaN  2.735938   5.247031
# Iowa                              NaN       NaN  0.937951   2.336217
# Kansas                            NaN       NaN  2.421053   3.996036
# Kentucky                          NaN       NaN  2.676801   5.209202
# Louisiana                         NaN       NaN  3.949197   5.187228
# Maine                             NaN       NaN  0.621563   3.782596
# Maryland                          NaN       NaN  1.413992   4.304566
# Massachusetts                     0.0  0.000000  0.999203   4.395215
# Michigan                          NaN       NaN  1.669892   7.585991
# Minnesota                         NaN       NaN  0.735000   4.819681
# Mississippi                       NaN       NaN  1.494342   3.622369
# Missouri                          NaN       NaN  1.580135   3.754761
# Montana                           NaN       NaN  1.053093   2.431598
# Nebraska                          NaN  0.000000  0.766551   1.976550
# Nevada                            NaN       NaN  2.824954   4.399773
# New Hampshire                     NaN       NaN  0.768861   2.711379
# New Jersey                        NaN       NaN  1.646140   5.356230
# New Mexico                        NaN       NaN  0.749866   2.939796
# New York                          NaN       NaN  1.736807   5.716482
# North Carolina                    NaN       NaN  0.358754   2.804071
# North Dakota                      NaN       NaN  1.043705   1.986777
# Northern Mariana Islands          NaN       NaN  0.000000  15.254237
# Ohio                              NaN       NaN  1.800686   4.360089
# Oklahoma                          NaN       NaN  3.288296   5.440554
# Oregon                            NaN  0.000000  2.775956   3.607634
# Pennsylvania                      NaN       NaN  1.111250   3.516311
# Puerto Rico                       NaN       NaN  3.564155   5.470171
# Rhode Island                      NaN       NaN  0.321970   2.064773
# South Carolina                    NaN       NaN  1.978344   2.879932
# South Dakota                      NaN       NaN  4.484933   0.625129
# Tennessee                         NaN       NaN  0.483991   1.968722
# Texas                             NaN  0.000000  1.338240   2.453227
# United States Virgin Islands      NaN       NaN  0.000000   3.866667
# Utah                              NaN  0.000000  0.344141   0.849688
# Vermont                           NaN       NaN  4.012036   4.370511
# Virginia                          NaN       NaN  2.319116   3.149803
# Washington                        0.0  5.607477  4.570152   5.012880
# Washington, D.C.                  NaN       NaN  1.482291   3.781444
# West Virginia                     NaN       NaN  0.311915   2.365495
# Wisconsin                         NaN  0.000000  1.241518   4.136200
# Wyoming                           NaN       NaN  0.000000   0.832318
#
# month                           2020-05   2020-06   2020-07   2020-08  \
# state
# Alabama                        3.891484  2.966740  1.994896  1.763196
# Alaska                         2.489694  1.653788  0.926213  0.637709
# Arizona                        4.763857  2.896135  1.942851  2.318025
# Arkansas                       2.113971  1.466688  1.114127  1.167084
# California                     4.013291  3.196154  2.072309  1.836988
# Colorado                       5.053553  5.031730  4.397490  3.585565
# Connecticut                    9.012817  9.326114  9.314942  8.897749
# Delaware                       4.300814  4.474610  3.941114  3.597337
# Florida                        4.355050  3.451982  1.540909  1.646671
# Georgia                        4.429941  4.199546  2.467572  2.051574
# Guam                           3.165850  2.457808  1.576325  0.919508
# Hawaii                         2.685199  2.302484  1.641903  0.799059
# Idaho                          3.024576  2.279104  0.922600  0.999281
# Illinois                       4.430684  4.801614  4.558494  3.751755
# Indiana                        6.107318  5.314359  5.314359  5.314359
# Iowa                           2.439318  2.683083  2.104791  1.864442
# Kansas                         2.317514  2.114657  1.450417  1.172521
# Kentucky                       4.622429  3.990639  3.016682  2.173405
# Louisiana                      6.913564  6.131184  3.932215  3.143018
# Maine                          4.181612  3.582203  3.164334  3.037424
# Maryland                       4.993606  4.719648  4.361170  3.644707
# Massachusetts                  6.526266  7.265110  7.507871  7.284110
# Michigan                       9.336315  9.065345  8.094677  6.591677
# Minnesota                      4.266061  4.192363  3.454097  2.665107
# Mississippi                    4.592998  4.455776  3.208702  2.893578
# Missouri                       5.840441  5.567382  3.352857  1.771165
# Montana                        3.443073  2.935975  1.570684  1.449218
# Nebraska                       1.248276  1.342566  1.346904  1.201623
# Nevada                         5.164451  3.885566  1.957495  1.778496
# New Hampshire                  4.651725  5.977438  6.411706  6.090819
# New Jersey                     7.483364  8.189283  8.389390  8.004078
# New Mexico                     4.331597  4.446030  3.598706  3.155332
# New York                       7.058102  7.378815  7.088912  6.817321
# North Carolina                 3.474942  2.477884  1.706834  1.616542
# North Dakota                   2.011621  2.276704  1.861065  1.408089
# Northern Mariana Islands      10.526316  6.968641  5.672461  3.934010
# Ohio                           5.865761  6.026122  4.408165  3.552504
# Oklahoma                       5.530634  3.908145  1.883376  1.391411
# Oregon                         3.838614  2.984381  1.895326  1.704858
# Pennsylvania                   6.820038  7.642140  6.875404  5.902273
# Puerto Rico                    2.404588  1.281751  0.797061  0.654973
# Rhode Island                   3.933127  4.960250  2.912268  2.620692
# South Carolina                 4.343717  2.894691  1.759180  2.131892
# South Dakota                   1.089044  1.289886  1.445053  1.440220
# Tennessee                      1.655436  1.518993  1.111554  1.071420
# Texas                          2.735151  2.028833  1.311913  1.793534
# United States Virgin Islands   7.797732  8.071749  2.661851  1.327903
# Utah                           1.043903  0.712138  0.516989  0.548039
# Vermont                        5.705068  4.968406  4.248350  3.834720
# Virginia                       3.315815  2.861739  2.644603  2.254179
# Washington                     5.159585  4.398433  3.102134  2.616426
# Washington, D.C.               5.255162  5.290654  5.123919  4.527440
# West Virginia                  4.116128  3.643976  2.150212  1.893011
# Wisconsin                      3.386921  2.844883  2.018998  1.542753
# Wyoming                        1.312168  1.533579  0.578722  0.500970
#
# month                          2020-09   2020-10
# state
# Alabama                       1.731573  1.617441
# Alaska                        0.686523  0.698936
# Arizona                       2.553104  2.586501
# Arkansas                      1.511983  1.653582
# California                    1.898535  1.936102
# Colorado                      3.168521  2.844382
# Connecticut                   8.464212  8.072824
# Delaware                      3.403788  3.409858
# Florida                       1.920335  2.039327
# Georgia                       2.194885  2.248769
# Guam                          1.414025  1.928566
# Hawaii                        0.968586  0.974277
# Idaho                         1.159035  1.105485
# Illinois                      3.145472  2.921012
# Indiana                       5.314359  5.314359
# Iowa                          1.616292  1.500646
# Kansas                        1.097486  1.132717
# Kentucky                      1.837774  1.706935
# Louisiana                     3.186258  3.201874
# Maine                         2.768887  2.575669
# Maryland                      3.282946  3.117740
# Massachusetts                 7.491966  7.379614
# Michigan                      5.628402  5.138678
# Minnesota                     2.250663  2.044012
# Mississippi                   3.007511  3.001486
# Missouri                      1.477161  1.477571
# Montana                       1.458478  1.296510
# Nebraska                      1.108602  1.053487
# Nevada                        1.984882  1.980475
# New Hampshire                 5.613963  5.169666
# New Jersey                    7.343364  6.922359
# New Mexico                    3.139702  3.011314
# New York                      7.133235  7.149678
# North Carolina                1.658951  1.669254
# North Dakota                  1.106921  1.160046
# Northern Mariana Islands      3.164557  2.724796
# Ohio                          3.219612  3.105734
# Oklahoma                      1.266365  1.157214
# Oregon                        1.718041  1.649574
# Pennsylvania                  5.239855  4.898251
# Puerto Rico                   0.720457  0.691927
# Rhode Island                  2.430878  2.339494
# South Carolina                2.312082  2.281490
# South Dakota                  1.085406  1.017048
# Tennessee                     1.217759  1.297119
# Texas                         2.029069  2.027472
# United States Virgin Islands  1.476543  1.508751
# Utah                          0.520055  0.577474
# Vermont                       3.434900  3.264663
# Virginia                      2.124989  2.160076
# Washington                    2.502029  2.400467
# Washington, D.C.              4.195246  4.071392
# West Virginia                 2.185585  1.999395
# Wisconsin                     1.273027  1.049491
# Wyoming                       0.963207  0.689673
# CFR Change Ranking:
#  state
# Massachusetts                   7.379614
# Connecticut                     6.139336
# New York                        5.412871
# New Jersey                      5.276219
# New Hampshire                   4.400805
# Pennsylvania                    3.787001
# Michigan                        3.468785
# Illinois                        2.921012
# Northern Mariana Islands        2.724796
# Washington, D.C.                2.589101
# Arizona                         2.586501
# Indiana                         2.578422
# Washington                      2.400467
# New Mexico                      2.261448
# Texas                           2.027472
# Rhode Island                    2.017525
# Maine                           1.954106
# California                      1.936102
# Maryland                        1.703749
# West Virginia                   1.687479
# Oregon                          1.649574
# United States Virgin Islands    1.508751
# Mississippi                     1.507144
# North Carolina                  1.310499
# Minnesota                       1.309011
# Ohio                            1.305049
# Delaware                        1.074288
# Nebraska                        1.053487
# Wisconsin                       1.049491
# Colorado                        1.048188
# Alabama                         0.947098
# Hawaii                          0.823106
# Tennessee                       0.813128
# Arkansas                        0.722557
# Wyoming                         0.689673
# Florida                         0.636280
# Utah                            0.577474
# Iowa                            0.562695
# South Carolina                  0.303146
# Montana                         0.243417
# North Dakota                    0.116341
# Missouri                       -0.102564
# Virginia                       -0.159040
# Guam                           -0.203217
# Idaho                          -0.281445
# Alaska                         -0.642060
# Louisiana                      -0.747324
# Vermont                        -0.747373
# Georgia                        -0.800524
# Nevada                         -0.844479
# Kentucky                       -0.969866
# Kansas                         -1.288336
# Oklahoma                       -2.131082
# Puerto Rico                    -2.872227
# South Dakota                   -3.467885
# dtype: float64

# %% [markdown]
# **Question 3c**
#
# **Approach Used**
#
# The approach used in the code follows the naïve CFR method as defined by the World Health Organization (WHO) in their scientific brief:
#
# The method used in the code aggregates the number of deaths and cases per state per month and then computes the ratio of deaths to cases.
# This corresponds to the Crude CFR approach outlined by WHO, where:
# This approach does not account for the lag between infection and death, which means it might slightly underestimate or overestimate the actual CFR.
#
# **Assumptions Made**
#
# Deaths are correctly attributed to the state and time period in the dataset.
# Case and death data are complete and accurate (no missing cases or underreporting).
# No significant lag between case reporting and death is considered, which may cause some inaccuracies.
# Population sizes are stable throughout the given time period.

# %% [markdown]
# **Question 4**
#
# Using Dask is beneficial due to:
# 1. Large dataset size: COVID-19 time series data is large, requiring parallel computing.
# 2. Aggregations: Operations like grouping, summing, and computing CFR benefit from parallel execution.
# 3. Speed: Dask efficiently handles operations on a distributed computing framework.
